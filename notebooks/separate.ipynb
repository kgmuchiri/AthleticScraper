# %% [markdown]
# # Adding Columns

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../all_disciplines_combined.csv')
df2 = pd.read_csv('../all_disciplines_combined.csv')
# Out:
# /var/folders/92/yrzy6lgs0hx75g3j4tsnw8n40000gp/T/ipykernel_90864/891636340.py:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../all_disciplines_combined.csv')
# /var/folders/92/yrzy6lgs0hx75g3j4tsnw8n40000gp/T/ipykernel_90864/891636340.py:2: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv('../all_disciplines_combined.csv')

# %%
df.tail(10)
# Out:
#         Rank      Mark  Wind          Competitor         DOB Nationality  \
# 501543   366  11:49.5h   NaN       Nick CHRISTIE  1991-09-29         USA
# 501544   366  11:49.50   NaN        Dušan MAJDAN  1987-09-08         SVK
# 501545   368  11:49.53   NaN  Cameron CORBISHLEY  1997-03-31         GBR
# 501546   368  11:49.53   NaN          Ian RAYSON  1988-02-04         AUS
# 501547   370  11:49.60   NaN          Vít HLAVÁČ  1997-02-26         CZE
# 501548   371  11:49.7h   NaN      Travis HARBOUR         NaN         AUS
# 501549   372  11:49.72   NaN      Anthony PETERS  1996-04-23         USA
# 501550   373  11:49.85   NaN    Callum WILKINSON  1997-03-14         GBR
# 501551   374  11:49.9h   NaN      Mikita KALIADA  2000-07-15         BLR
# 501552   375  11:49.93   NaN       Brendan BOYCE  1986-10-08         IRL
#
#        Position                                   Venue        Date  \
# 501543        1                     San Diego, CA (USA)  2018-01-28
# 501544        2               Banská Bystrica (SVK) (i)  2016-01-05
# 501545        2  Arena Birmingham, Birmingham (GBR) (i)  2025-02-23
# 501546        1                          Canberra (AUS)  2014-01-09
# 501547        1  Atletický stadion Turnov, Turnov (CZE)  2022-05-24
# 501548        1                         Melbourne (AUS)  1997-02-01
# 501549        1              Johnson City, TN (USA) (i)  2017-03-03
# 501550        1                        Manchester (GBR)  2016-08-17
# 501551        1                         Brest (BLR) (i)  2016-02-10
# 501552        3                           Bedford (GBR)  2010-05-31
#
#         Result Score  ...        Type Gender Age Category  \
# 501543        1056.0  ...  race-walks   male       senior
# 501544        1056.0  ...  race-walks   male       senior
# 501545        1056.0  ...  race-walks   male       senior
# 501546        1056.0  ...  race-walks   male       senior
# 501547        1056.0  ...  race-walks   male       senior
# 501548        1056.0  ...  race-walks   male       senior
# 501549           0.0  ...  race-walks   male       senior
# 501550        1056.0  ...  race-walks   male       senior
# 501551        1055.0  ...  race-walks   male       senior
# 501552        1055.0  ...  race-walks   male       senior
#
#          normalized_discpline track_field mark_numeric  venue_country_code  \
# 501543  3000-metres-race-walk       track       709.50                 USA
# 501544  3000-metres-race-walk       track       709.50                 SVK
# 501545  3000-metres-race-walk       track       709.53                 GBR
# 501546  3000-metres-race-walk       track       709.53                 AUS
# 501547  3000-metres-race-walk       track       709.60                 CZE
# 501548  3000-metres-race-walk       track       709.70                 AUS
# 501549  3000-metres-race-walk       track       709.72                 USA
# 501550  3000-metres-race-walk       track       709.85                 GBR
# 501551  3000-metres-race-walk       track       709.90                 BLR
# 501552  3000-metres-race-walk       track       709.93                 GBR
#
#        age_at_event  season                                source_file
# 501543         26.0    2018  male_race-walks_3000-metres-race-walk.csv
# 501544         28.0    2016  male_race-walks_3000-metres-race-walk.csv
# 501545         27.0    2025  male_race-walks_3000-metres-race-walk.csv
# 501546         25.0    2014  male_race-walks_3000-metres-race-walk.csv
# 501547         25.0    2022  male_race-walks_3000-metres-race-walk.csv
# 501548          NaN    1997  male_race-walks_3000-metres-race-walk.csv
# 501549         20.0    2017  male_race-walks_3000-metres-race-walk.csv
# 501550         19.0    2016  male_race-walks_3000-metres-race-walk.csv
# 501551         15.0    2016  male_race-walks_3000-metres-race-walk.csv
# 501552         23.0    2010  male_race-walks_3000-metres-race-walk.csv
#
# [10 rows x 21 columns]

# %%
df=df.drop("source_file",axis=1)
df2=df2.drop("source_file",axis=1)
df2=df2.drop("DOB",axis=1)
df2=df2.drop("age_at_event",axis=1)

# %%
df = df[df["Type"] != "relays"]
df2 = df2[df2["Type"] == "relays"]

# %%
df.head(10)
# Out:
#       Rank   Mark  Wind            Competitor         DOB Nationality  \
# 1087     1  24.45   NaN            Jacko GILL  1994-12-20         NZL
# 1088     2  24.35   NaN            Jacko GILL  1994-12-20         NZL
# 1089     3  24.24   NaN     Konrad BUKOWIECKI  1997-03-17         POL
# 1090     4  23.86   NaN            Jacko GILL  1994-12-20         NZL
# 1091     1  23.56   NaN          Ryan CROUSER  1992-12-18         USA
# 1092     2  23.51   NaN          Ryan CROUSER  1992-12-18         USA
# 1093     3  23.37   NaN          Ryan CROUSER  1992-12-18         USA
# 1094     4   23.3   NaN          Ryan CROUSER  1992-12-18         USA
# 1095     5  23.23   NaN  Krzysztof BRZOZOWSKI  1993-07-15         POL
# 1096     5  23.23   NaN            Joe KOVACS  1989-06-28         USA
#
#      Position                                      Venue        Date  \
# 1087        1                             Auckland (NZL)  2011-12-19
# 1088        1                                Lille (FRA)  2011-07-07
# 1089        1                            Spala (POL) (i)  2014-12-30
# 1090        1                             Hastings (NZL)  2010-12-11
# 1091        1       Drake Stadium, Los Angeles, CA (USA)  2023-05-27
# 1092        1  Nemzeti Atlétikai Központ, Budapest (HUN)  2023-08-19
# 1093        1            Hayward Field, Eugene, OR (USA)  2021-06-18
# 1094        1              National Stadium, Tokyo (JPN)  2021-08-05
# 1095      1f2                            Singapore (SGP)  2010-08-22
# 1096        1            Sechseläutenplatz, Zürich (SUI)  2022-09-07
#
#       Result Score    Discipline    Type Gender Age Category  \
# 1087           NaN  shot-put-5kg  throws   male          u18
# 1088           NaN  shot-put-5kg  throws   male          u18
# 1089           NaN  shot-put-5kg  throws   male          u18
# 1090           NaN  shot-put-5kg  throws   male          u18
# 1091        1334.0      shot-put  throws   male       senior
# 1092        1331.0      shot-put  throws   male       senior
# 1093        1323.0      shot-put  throws   male       senior
# 1094        1318.0      shot-put  throws   male       senior
# 1095           NaN  shot-put-5kg  throws   male          u18
# 1096        1314.0      shot-put  throws   male       senior
#
#      normalized_discpline track_field  mark_numeric venue_country_code  \
# 1087             shot-put       field         24.45                NZL
# 1088             shot-put       field         24.35                FRA
# 1089             shot-put       field         24.24                POL
# 1090             shot-put       field         23.86                NZL
# 1091             shot-put       field         23.56                USA
# 1092             shot-put       field         23.51                HUN
# 1093             shot-put       field         23.37                USA
# 1094             shot-put       field         23.30                JPN
# 1095             shot-put       field         23.23                SGP
# 1096             shot-put       field         23.23                SUI
#
#       age_at_event  season
# 1087          17.0    2011
# 1088          16.0    2011
# 1089          17.0    2014
# 1090          15.0    2010
# 1091          30.0    2023
# 1092          30.0    2023
# 1093          28.0    2021
# 1094          28.0    2021
# 1095          17.0    2010
# 1096          33.0    2022

# %%
df.to_csv("../datasets/individual_events.csv", index=False)
df2.to_csv("../datasets/relay_events.csv", index=False)

# %%
import os

# Make sure output directory exists
output_dir = "../datasets/split_by_type"
os.makedirs(output_dir, exist_ok=True)

# Group by 'type' and save each group as a separate CSV
for event_type, df_group in df.groupby("Type"):
    filename = f"{event_type}.csv"
    filepath = os.path.join(output_dir, filename)
    df_group.to_csv(filepath, index=False)
    print(f"✅ Saved: {filepath}")
# Out:
# ✅ Saved: ../datasets/split_by_type/combined-events.csv
# ✅ Saved: ../datasets/split_by_type/hurdles.csv
# ✅ Saved: ../datasets/split_by_type/jumps.csv
# ✅ Saved: ../datasets/split_by_type/race-walks.csv
# ✅ Saved: ../datasets/split_by_type/road-running.csv
# ✅ Saved: ../datasets/split_by_type/sprints.csv
# ✅ Saved: ../datasets/split_by_type/throws.csv
